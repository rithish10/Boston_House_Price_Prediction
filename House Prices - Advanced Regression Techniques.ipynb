# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns 
# %matplotlib inline

# %%
data = pd.read_csv('train.csv')
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
datat = pd.read_csv('test.csv')
datat.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
frames=[data,datat]
data=pd.concat(frames) 
data
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch Alley  BedroomAbvGr BldgType BsmtCond  \
# 0          856       854          0   NaN             3     1Fam       TA
# 1         1262         0          0   NaN             3     1Fam       TA
# 2          920       866          0   NaN             3     1Fam       TA
# 3          961       756          0   NaN             3     1Fam       Gd
# 4         1145      1053          0   NaN             4     1Fam       TA
# 5          796       566        320   NaN             1     1Fam       TA
# 6         1694         0          0   NaN             3     1Fam       TA
# 7         1107       983          0   NaN             3     1Fam       TA
# 8         1022       752          0   NaN             2     1Fam       TA
# 9         1077         0          0   NaN             2   2fmCon       TA
# 10        1040         0          0   NaN             3     1Fam       TA
# 11        1182      1142          0   NaN             4     1Fam       TA
# ...

# %%
data.set_index('Id',inplace=True)

# %%
for i in data.columns:
    if data[i].dtypes == 'object':#lotShape,HouseStyle,Condition1
        print (data[i].value_counts()) #SaleType , MiscFeatu,Fence,GarageCond/Qual,FireplaceQu,KitchenQual,CentralAir,BsmtFinType2,type1,BsmtQual,ExterQual,RoofStyle,
# Out:
# Grvl    120
# Pave     78
# Name: Alley, dtype: int64
# 1Fam      2425
# TwnhsE     227
# Duplex     109
# Twnhs       96
# 2fmCon      62
# Name: BldgType, dtype: int64
# TA    2606
# Gd     122
# Fa     104
# Po       5
# Name: BsmtCond, dtype: int64
# No    1904
# Av     418
# Gd     276
# Mn     239
# Name: BsmtExposure, dtype: int64
# Unf    851
# GLQ    849
# ALQ    429
# Rec    288
# BLQ    269
# LwQ    154
# Name: BsmtFinType1, dtype: int64
# Unf    2493
# Rec     105
# LwQ      87
# BLQ      68
# ALQ      52
# GLQ      34
# Name: BsmtFinType2, dtype: int64
# TA    1283
# Gd    1209
# Ex     258
# Fa      88
# Name: BsmtQual, dtype: int64
# Y    2723
# N     196
# Name: CentralAir, dtype: int64
# Norm      2511
# Feedr      164
# Artery      92
# RRAn        50
# PosN        39
# RRAe        28
# PosA        20
# RRNn         9
# RRNe         6
# Name: Condition1, dtype: int64
# Norm      2889
# Feedr       13
# Artery       5
# PosN         4
# PosA         4
# ...

# %%
data.select_dtypes(include=['object']).isnull().sum()
# Out:
# Alley            2721
# BldgType            0
# BsmtCond           82
# BsmtExposure       82
# BsmtFinType1       79
# BsmtFinType2       80
# BsmtQual           81
# CentralAir          0
# Condition1          0
# Condition2          0
# Electrical          1
# ExterCond           0
# ExterQual           0
# Exterior1st         1
# Exterior2nd         1
# Fence            2348
# FireplaceQu      1420
# Foundation          0
# Functional          2
# GarageCond        159
# GarageFinish      159
# GarageQual        159
# GarageType        157
# Heating             0
# HeatingQC           0
# HouseStyle          0
# KitchenQual         1
# LandContour         0
# LandSlope           0
# LotConfig           0
# LotShape            0
# MSZoning            4
# MasVnrType         24
# MiscFeature      2814
# Neighborhood        0
# PavedDrive          0
# PoolQC           2909
# RoofMatl            0
# RoofStyle           0
# SaleCondition       0
# SaleType            1
# ...

# %%
for i in data.columns:
    if data[i].dtypes=='object':
        data[i]=data[i].fillna('Missing')

# %%
data.select_dtypes(include=['object']).isnull().sum()
# Out:
# Alley            0
# BldgType         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinType2     0
# BsmtQual         0
# CentralAir       0
# Condition1       0
# Condition2       0
# Electrical       0
# ExterCond        0
# ExterQual        0
# Exterior1st      0
# Exterior2nd      0
# Fence            0
# FireplaceQu      0
# Foundation       0
# Functional       0
# GarageCond       0
# GarageFinish     0
# GarageQual       0
# GarageType       0
# Heating          0
# HeatingQC        0
# HouseStyle       0
# KitchenQual      0
# LandContour      0
# LandSlope        0
# LotConfig        0
# LotShape         0
# MSZoning         0
# MasVnrType       0
# MiscFeature      0
# Neighborhood     0
# PavedDrive       0
# PoolQC           0
# RoofMatl         0
# RoofStyle        0
# SaleCondition    0
# SaleType         0
# Street           0
# Utilities        0
# dtype: int64

# %%
data.select_dtypes(exclude='object').isnull().sum()
# Out:
# 1stFlrSF            0
# 2ndFlrSF            0
# 3SsnPorch           0
# BedroomAbvGr        0
# BsmtFinSF1          1
# BsmtFinSF2          1
# BsmtFullBath        2
# BsmtHalfBath        2
# BsmtUnfSF           1
# EnclosedPorch       0
# Fireplaces          0
# FullBath            0
# GarageArea          1
# GarageCars          1
# GarageYrBlt       159
# GrLivArea           0
# HalfBath            0
# KitchenAbvGr        0
# LotArea             0
# LotFrontage       486
# LowQualFinSF        0
# MSSubClass          0
# MasVnrArea         23
# MiscVal             0
# MoSold              0
# OpenPorchSF         0
# OverallCond         0
# OverallQual         0
# PoolArea            0
# SalePrice        1459
# ScreenPorch         0
# TotRmsAbvGrd        0
# TotalBsmtSF         1
# WoodDeckSF          0
# YearBuilt           0
# YearRemodAdd        0
# YrSold              0
# dtype: int64

# %%
from sklearn.preprocessing import Imputer

# %%
cols = ['TotalBsmtSF','MasVnrArea','LotFrontage','GarageYrBlt' ,'GarageCars','GarageArea','BsmtFinSF1','BsmtFinSF2','BsmtFullBath','BsmtHalfBath','BsmtUnfSF']
im=Imputer(missing_values='NaN', strategy='mean',axis=0)
for x in cols:
    imputer=im.fit(data[x].reshape(-1, 1))
    data[x]=imputer.transform(data[x].reshape(-1, 1))
# Out:
# /media/akki/0C77C1DB5023617A/Downloads/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:4: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   after removing the cwd from sys.path.
# /media/akki/0C77C1DB5023617A/Downloads/anaconda/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
#   """

# %%
data.select_dtypes(exclude='object').isnull().sum()
# Out:
# 1stFlrSF            0
# 2ndFlrSF            0
# 3SsnPorch           0
# BedroomAbvGr        0
# BsmtFinSF1          0
# BsmtFinSF2          0
# BsmtFullBath        0
# BsmtHalfBath        0
# BsmtUnfSF           0
# EnclosedPorch       0
# Fireplaces          0
# FullBath            0
# GarageArea          0
# GarageCars          0
# GarageYrBlt         0
# GrLivArea           0
# HalfBath            0
# KitchenAbvGr        0
# LotArea             0
# LotFrontage         0
# LowQualFinSF        0
# MSSubClass          0
# MasVnrArea          0
# MiscVal             0
# MoSold              0
# OpenPorchSF         0
# OverallCond         0
# OverallQual         0
# PoolArea            0
# SalePrice        1459
# ScreenPorch         0
# TotRmsAbvGrd        0
# TotalBsmtSF         0
# WoodDeckSF          0
# YearBuilt           0
# YearRemodAdd        0
# YrSold              0
# dtype: int64

# %%
data.shape
# Out:
# (2919, 80)

# %%
data['SaleCondition'] = ['Normal' if x == 'Normal'  else 'Other' for x in data['SaleCondition']]

print(data['SaleCondition'].value_counts().sort_values(ascending=False))
# Out:
# Normal    2402
# Other      517
# Name: SaleCondition, dtype: int64

# %%
data['SaleType'] = ['WD' if x == 'WD'  else 'Other' for x in data['SaleType']]

print(data['SaleType'].value_counts().sort_values(ascending=False))
# Out:
# WD       2525
# Other     394
# Name: SaleType, dtype: int64

# %%
data['PavedDrive'] = ['Y' if x == 'Y'  else 'Other' for x in data['PavedDrive']]

print(data['PavedDrive'].value_counts().sort_values(ascending=False))
# Out:
# Y        2641
# Other     278
# Name: PavedDrive, dtype: int64

# %%
data['MiscFeature'] = ['Missing' if x == 'Missing'  else 'Known' for x in data['MiscFeature']]

print(data['MiscFeature'].value_counts().sort_values(ascending=False))
# Out:
# Missing    2814
# Known       105
# Name: MiscFeature, dtype: int64

# %%
data['LotShape'] = ['Reg' if x == 'Reg'  else 'IR' for x in data['LotShape']]

print(data['LotShape'].value_counts().sort_values(ascending=False))
# Out:
# Reg    1859
# IR     1060
# Name: LotShape, dtype: int64

# %%
data['LotShape'] = ['Reg' if x == 'Reg'  else 'IR' for x in data['LotShape']]

print(data['LotShape'].value_counts().sort_values(ascending=False))
data['LandContour'] = ['Lvl' if x == 'Lvl'  else 'Other' for x in data['LandContour']]

print(data['LandContour'].value_counts().sort_values(ascending=False))
data['Condition1'] = ['Norm' if x == 'Norm'  else 'Other' for x in data['Condition1']]
data['Condition2'] = ['Norm' if x == 'Norm'  else 'Other' for x in data['Condition2']]
print(data['Condition1'].value_counts().sort_values(ascending=False))
data['RoofStyle'] = ['Gable' if x == 'Gable'  else 'Other' for x in data['RoofStyle']]
data['GarageQual'] = ['TA' if x == 'TA'  else 'Other' for x in data['GarageQual']]
#RoofMatl
data['RoofMatl'] = ['CompShg' if x == 'CompShg'  else 'Other' for x in data['RoofMatl']]
data['ExterCond'] = ['TA' if x == 'TA'  else 'Other' for x in data['ExterCond']]
data['BsmtCond'] = ['TA' if x == 'TA'  else 'Other' for x in data['BsmtCond']]
data['BsmtFinType2'] = ['Unf' if x == 'Unf'  else 'Other' for x in data['BsmtFinType2']]
data['Heating'] = ['GasB' if x == 'GasB'  else 'Other' for x in data['Heating']]
data['Electrical'] = ['SBrkr' if x == 'SBrkr'  else 'Other' for x in data['Electrical']]
data['Functional'] = ['Typ' if x == 'Typ'  else 'Other' for x in data['Functional']]
data['GarageCond'] = ['TA' if x == 'TA'  else 'Other' for x in data['GarageCond']]
# Out:
# Reg    1859
# IR     1060
# Name: LotShape, dtype: int64
# Lvl      2622
# Other     297
# Name: LandContour, dtype: int64
# Norm     2511
# Other     408
# Name: Condition1, dtype: int64

# %%
for i in data.columns:
    if data[i].dtypes == 'object':#lotShape,HouseStyle,Condition1
        print (data[i].value_counts()) #SaleType , MiscFeatu,Fence,GarageCond/Qual,FireplaceQu,KitchenQual,CentralAir,BsmtFinType2,type1,BsmtQual,ExterQual,RoofStyle,
# Out:
# Missing    2721
# Grvl        120
# Pave         78
# Name: Alley, dtype: int64
# 1Fam      2425
# TwnhsE     227
# Duplex     109
# Twnhs       96
# 2fmCon      62
# Name: BldgType, dtype: int64
# TA       2606
# Other     313
# Name: BsmtCond, dtype: int64
# No         1904
# Av          418
# Gd          276
# Mn          239
# Missing      82
# Name: BsmtExposure, dtype: int64
# Unf        851
# GLQ        849
# ALQ        429
# Rec        288
# BLQ        269
# LwQ        154
# Missing     79
# Name: BsmtFinType1, dtype: int64
# Unf      2493
# Other     426
# Name: BsmtFinType2, dtype: int64
# TA         1283
# Gd         1209
# Ex          258
# Fa           88
# Missing      81
# Name: BsmtQual, dtype: int64
# Y    2723
# N     196
# Name: CentralAir, dtype: int64
# Norm     2511
# Other     408
# Name: Condition1, dtype: int64
# Norm     2889
# Other      30
# Name: Condition2, dtype: int64
# SBrkr    2671
# Other     248
# Name: Electrical, dtype: int64
# TA       2538
# ...

# %%
data['MSZoning'] = ['RL' if x == 'RL'  else 'Other' for x in data['MSZoning']]

# %%
data.drop(['Alley','FireplaceQu','PoolQC','Fence','MiscFeature'], axis = 1, inplace = True)

# %%
to_dummylist=[]
for x in data.columns:
    if data[x].dtypes=='object':
        to_dummylist.append(x)
print (to_dummylist)
# Out:
# ['BldgType', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'BsmtQual', 'CentralAir', 'Condition1', 'Condition2', 'Electrical', 'ExterCond', 'ExterQual', 'Exterior1st', 'Exterior2nd', 'Foundation', 'Functional', 'GarageCond', 'GarageFinish', 'GarageQual', 'GarageType', 'Heating', 'HeatingQC', 'HouseStyle', 'KitchenQual', 'LandContour', 'LandSlope', 'LotConfig', 'LotShape', 'MSZoning', 'MasVnrType', 'Neighborhood', 'PavedDrive', 'RoofMatl', 'RoofStyle', 'SaleCondition', 'SaleType', 'Street', 'Utilities']

# %%
def dummy_df(df, to_dummylist):
    for x in to_dummylist:
        dummies = pd.get_dummies(df[x], prefix=x, dummy_na=False)
        df = df.drop(x, 1)
        df = pd.concat([df, dummies], axis=1)
    return df

# %%
X=data.drop(labels='SalePrice',axis=1)
X = dummy_df(X, to_dummylist)
print(X.head(5))
# Out:
#     1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# Id
# 1        856       854          0             3       706.0         0.0
# 2       1262         0          0             3       978.0         0.0
# 3        920       866          0             3       486.0         0.0
# 4        961       756          0             3       216.0         0.0
# 5       1145      1053          0             4       655.0         0.0
#
#     BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch        ...         \
# Id                                                              ...
# 1            1.0           0.0      150.0              0        ...
# 2            0.0           1.0      284.0              0        ...
# 3            1.0           0.0      434.0              0        ...
# 4            1.0           0.0      540.0            272        ...
# 5            1.0           0.0      490.0              0        ...
#
# ...

# %%
#Data Preprocessing 
from sklearn.preprocessing import StandardScaler
#making a pipeline 
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression , ElasticNet, Ridge, Lasso
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
pipe={
    'Enet':make_pipeline(StandardScaler(),ElasticNet()),
       'ridge':make_pipeline(StandardScaler(),Ridge()),
       'lasso':make_pipeline(StandardScaler(),Lasso()),
    'rf':make_pipeline(StandardScaler(), RandomForestRegressor()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingRegressor())
}     
pipe1={'Linear':make_pipeline(StandardScaler(),LinearRegression),}

# %%
#Checking the pipe 
for key , values in pipe.items():
    print(key , type(values))
# Out:
# Enet <class 'sklearn.pipeline.Pipeline'>
# ridge <class 'sklearn.pipeline.Pipeline'>
# lasso <class 'sklearn.pipeline.Pipeline'>
# rf <class 'sklearn.pipeline.Pipeline'>
# gb <class 'sklearn.pipeline.Pipeline'>

# %%
#Decalring the hyperparameters 
lasso_hyperparameters = { 'lasso__alpha' : [0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10] }
ridge_hyperparameters = { 'ridge__alpha': [0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10] }
enet_hyperparameters = { 'elasticnet__alpha': [0.001, 0.005, 0.01, 0.05, 0.1, 0.5, 1, 5, 10], 
                       'elasticnet__l1_ratio': [0.1, 0.3, 0.5, 0.7, 0.9]}
rf_hyperparameters = { 
    'randomforestregressor__n_estimators' : [100, 200],
    'randomforestregressor__max_features': ['auto', 'sqrt', 0.33],
}
gb_hyperparameters = { 'gradientboostingregressor__n_estimators': [100, 200],
                     'gradientboostingregressor__learning_rate': [0.05, 0.1, 0.2],
                     'gradientboostingregressor__max_depth': [1, 3, 5]}

# %%
#Creating hyperparameters Dictionary 
hyperparameters={
    'lasso' : lasso_hyperparameters,
    'ridge' : ridge_hyperparameters,
    'Enet' : enet_hyperparameters,
    'rf' : rf_hyperparameters,
    'gb' : gb_hyperparameters
}

# %%
y=data['SalePrice']
y_train=y[:1460]
X_train=X[:1460]
X_test=X[1460:]

# %%
#Fit and Tune using cross-validation 
fitted_models = {}
# Helper for cross-validation
from sklearn.model_selection import GridSearchCV
for name , pipeline in pipe.items():
    model = GridSearchCV(pipeline , hyperparameters[name] ,cv =10 ,n_jobs=-1)
    model.fit(X_train,np.log(y_train))
    fitted_models[name]=model
    print(name, 'has been fitted.')
# Out:
# /media/akki/0C77C1DB5023617A/Downloads/anaconda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /media/akki/0C77C1DB5023617A/Downloads/anaconda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# /media/akki/0C77C1DB5023617A/Downloads/anaconda/lib/python3.6/site-packages/sklearn/linear_model/coordinate_descent.py:491: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Fitting data with very small alpha may cause precision problems.
#   ConvergenceWarning)
# ...

# %%
#Evalute the model 
for name, model in fitted_models.items():
    print(name, model.best_score_)#r2-values
# Out:
# Enet 0.8728820988603424
# ridge 0.8648082367394867
# lasso 0.8711964141687648
# rf 0.881013821483755
# gb 0.9010856469218617

# %%
#Evalute the model 
for name, model in fitted_models.items():
    if name == 'gb':
        lists=model.predict(X_test)#r2-values
print (lists)
# Out:
# [11.68815619 11.94542201 12.13632693 ... 11.9086231  11.64766743
#  12.35341026]

# %%
lists=np.exp(lists)
lists
# Out:
# array([119152.10992822, 154110.01578365, 186526.1895925 , ...,
#        148542.01034344, 114424.14862405, 231749.02028757])

# %%
df = pd.DataFrame(lists)
df
# Out:
#                   0
# 0     119152.109928
# 1     154110.015784
# 2     186526.189593
# 3     190297.177933
# 4     186310.789640
# 5     175565.855276
# 6     174074.884625
# 7     169087.674550
# 8     184290.796892
# 9     123976.655357
# 10    196411.659166
# 11     95956.761061
# 12     96127.502763
# 13    153914.638324
# 14    134424.113153
# 15    403278.305200
# 16    254654.996856
# 17    298312.684658
# 18    268954.142523
# 19    473435.111650
# 20    323801.154226
# 21    203832.108925
# 22    163052.553926
# 23    169148.900234
# 24    173825.051135
# 25    188385.044480
# 26    358025.296214
# 27    238066.219877
# 28    207747.381364
# 29    215049.445600
# ...             ...
# 1429   77297.357567
# 1430  130000.175727
# 1431   51222.038357
# 1432   97204.972064
# 1433   56283.054417
# 1434  281785.381748
# 1435  278223.506651
# 1436  194768.205138
# 1437  147716.247245
# 1438  223187.192159
# 1439  158610.588877
# 1440  203693.698976
# 1441  188112.522237
# ...

# %%
df.to_csv('example5.csv')
